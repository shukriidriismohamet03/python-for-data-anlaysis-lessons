# %% [markdown]
# **`import librarys`**

# %%
#import library pandan
#syntax for import (import library name as pd)
import pandas as pd

# %% [markdown]
# **load** **dataset**

# %%
#read data from google colab
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/CRIME-DATA-ANALYSIS-COMPLA.xlsx")

# %% [markdown]
# **#Undrestanding Dataset**

# %% [markdown]
# ## undrestanding first 5 rows uding heading fuction

# %%
##read

# %%
data.head()
# Out:
#    Crime_ID           Crime_Date Crime_Type District Victim_Gender  \
# 0  CRM00054  2025-07-11 00:00:00      Theft    Karan          Male
# 1  CRM00290  2025-02-26 00:00:00   Burglary      NaN          Male
# 2  CRM00143  2026-05-26 00:00:00      Theft  Wadajir        Female
# 3  CRM00198  2025-02-17 00:00:00    Assault  Wadajir          Male
# 4  CRM00244  2026-02-27 00:00:00    Assault    Hodan        Female
#
#            Case_Status Severity_Level
# 0               Closed            NaN
# 1               Closed         Medium
# 2                  NaN         Medium
# 3                 Open           High
# 4  Under Investigation           High

# %% [markdown]
# ## undrestanding last 5 rows uding heading fuction
#
# ---

# %%
data.tail()
# Out:
#      Crime_ID           Crime_Date       Crime_Type District Victim_Gender  \
# 295  CRM00052  2025-02-03 00:00:00          Robbery  Wadajir        Female
# 296  CRM00085  2025-12-09 00:00:00              NaN    Hodan          Male
# 297  CRM00057  2025-01-24 00:00:00  Traffic Offense   Waberi        Female
# 298  CRM00023  2025-02-23 00:00:00          Robbery  Wadajir          Male
# 299  CRM00077  2026-05-01 00:00:00  Traffic Offense    Hodan          Male
#
#              Case_Status Severity_Level
# 295  Under Investigation            NaN
# 296                 Open         Medium
# 297  Under Investigation            Low
# 298               Closed           High
# 299               Closed            NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Crime_ID        285 non-null    object
#  1   Crime_Date      282 non-null    object
#  2   Crime_Type      284 non-null    object
#  3   District        284 non-null    object
#  4   Victim_Gender   284 non-null    object
#  5   Case_Status     283 non-null    object
#  6   Severity_Level  280 non-null    object
# dtypes: object(7)
# memory usage: 16.5+ KB

# %%
data.sample(5)
# Out:
#      Crime_ID           Crime_Date       Crime_Type District Victim_Gender  \
# 211  CRM00071  2026-07-20 00:00:00  Traffic Offense  Daynile          Male
# 143  CRM00146  2025-07-12 00:00:00          Assault   Waberi        Female
# 200  CRM00148  2025-07-12 00:00:00            Theft  Wadajir       Unknown
# 199  CRM00188  2026-02-02 00:00:00          Assault  Wadajir        Female
# 285  CRM00055  2025-09-08 00:00:00  Traffic Offense   Waberi          Male
#
#              Case_Status Severity_Level
# 211               Closed            Low
# 143                 Open           High
# 200               Closed         Medium
# 199                 Open           High
# 285  Under Investigation            Low

# %% [markdown]
# # **show the display data shape**

# %%
data.shape
# Out:
# (300, 7)

# %% [markdown]
# this dataset 24 rows and 9 column

# %%
data.columns
# Out:
# Index(['Crime_ID', 'Crime_Date', 'Crime_Type', 'District', 'Victim_Gender',
#        'Case_Status', 'Severity_Level'],
#       dtype='object')

# %% [markdown]
# ## Display dta types my dtaset using propery using (datatype)

# %%
data.dtypes
# Out:
# Crime_ID          object
# Crime_Date        object
# Crime_Type        object
# District          object
# Victim_Gender     object
# Case_Status       object
# Severity_Level    object
# dtype: object

# %% [markdown]
# ## summary of dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Crime_ID        285 non-null    object
#  1   Crime_Date      282 non-null    object
#  2   Crime_Type      284 non-null    object
#  3   District        284 non-null    object
#  4   Victim_Gender   284 non-null    object
#  5   Case_Status     283 non-null    object
#  6   Severity_Level  280 non-null    object
# dtypes: object(7)
# memory usage: 16.5+ KB

# %% [markdown]
# ## display the describe of statistics using describe fuction

# %%
data.describe(include="all")
# Out:
#         Crime_ID           Crime_Date Crime_Type District Victim_Gender  \
# count        285                  282        284      284           284
# unique       277                  228          8        7             4
# top     CRM00013  2025-09-01 00:00:00      Theft    Hodan          Male
# freq           2                    4         82       74           162
#
#        Case_Status Severity_Level
# count          283            280
# unique           6              5
# top         Closed         Medium
# freq           115            150

# %%
data.describe()
# Out:
#         Crime_ID           Crime_Date Crime_Type District Victim_Gender  \
# count        285                  282        284      284           284
# unique       277                  228          8        7             4
# top     CRM00013  2025-09-01 00:00:00      Theft    Hodan          Male
# freq           2                    4         82       74           162
#
#        Case_Status Severity_Level
# count          283            280
# unique           6              5
# top         Closed         Medium
# freq           115            150

# %%
data.describe(include='object')
# Out:
#         Crime_ID           Crime_Date Crime_Type District Victim_Gender  \
# count        285                  282        284      284           284
# unique       277                  228          8        7             4
# top     CRM00013  2025-09-01 00:00:00      Theft    Hodan          Male
# freq           2                    4         82       74           162
#
#        Case_Status Severity_Level
# count          283            280
# unique           6              5
# top         Closed         Medium
# freq           115            150
